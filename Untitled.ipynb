# %%
# %reload_ext mocodo
# Out:
# Mocodo 4.3.2 loaded.

# %%
from IPython import display
from pathlib import Path
import os
if Path.cwd().name != "mocodo_notebook":
    Path("mocodo_notebook").mkdir(parents=True, exist_ok=True)
    os.chdir("mocodo_notebook")

# %%
# %%mocodo --colors brewer+3 -t
#
# Tâche: id, contenu, date limite, assigné à, priorité, progrès
# :
# ASSIGNED TO, 0N TÂCHE, 01 PERSONNE
# HABITER, NN Personne, NN Adresse
# Adresse: nom de rue, code postal, pays
# LOCALISER, NN Adresse, NN Ville
# Ville : nom
# SITUER 2, NN Ville, NN Pays
#
# /XT\ Resource <- Tâche, Personne
#     :
# Personne: email, nom de famille, prénom, date de naissance, téléphone, addresse, code postal, métier
# EMPLOYER, NN Organisation, NN Personne
# Organisation: nom
# SITUER 1, NN Organisation, NN Adresse
# :
# Pays: nom
#
# Resource: name, type
# MODIFIER, 1N User, 0N CLIENT, 0N DATABASE, 0N Resource
# /\ Personne <- User, Client
# User: email, mot de passe
# A, NN User, NN Role
# Role : name
# COMPOSER,  NN Permission, NN Role
# Permission: name
#
#
# Database: name,
# ACCEDER, 1N User, 0N CLIENT, 0N DATABASE, 0N Resource
# :
# Client: name, redirect_uri
# DEMANDER, NN CLIENT, NN AUTHORISATIONS
# AUTHORISATIONS: NAME
# :
#
# :
# CREER, 1N User, 0N CLIENT, 0N DATABASE, 0N Resource
# :
# :
# :
# :
# :
#
# :
# Refresh Token: token, client id, user id, expires at, revoked at
# HAS, 1N USER, 1N Client, 0N REFRESH TOKEN
# :
# :
# :
#
# :
#
# :
# :
# Out:
# - **A** (<u>_#name 1_</u>, <u>name 2</u>)
# - **ACCEDER** (<u>_#name 1_</u>, <u>_#name 2_</u>, <u>name 3</u>, <u>_#name 4_</u>)
# - **Adresse** (<u>nom de rue</u>, code postal, pays)
# - **COMPOSER** (<u>name 1</u>, <u>name 2</u>)
# - **CREER** (<u>_#name 1_</u>, <u>_#name 2_</u>, <u>name 3</u>, <u>_#name 4_</u>)
# - **DEMANDER** (<u>_#name_</u>, <u>NAME</u>)
# - **EMPLOYER** (<u>nom</u>, <u>_#name_</u>)
# - **HABITER** (<u>_#name_</u>, <u>_#nom de rue_</u>)
# - **HAS** (<u>_#name 1_</u>, <u>_#name 2_</u>, <u>_#token_</u>)
# - **LOCALISER** (<u>_#nom de rue_</u>, <u>nom</u>)
# - **MODIFIER** (<u>_#name 1_</u>, <u>_#name 2_</u>, <u>name 3</u>, <u>_#name 4_</u>)
# - **Refresh Token** (<u>token</u>, client id, user id, expires at, revoked at)
# - **Resource** (<u>name</u>, type, id, contenu, date limite, assigné à, priorité, progrès, email, nom de famille, prénom, date de naissance, téléphone, addresse, code postal, métier, _#name 2_)
# - **SITUER ** (<u>nom</u>, <u>_#nom de rue_</u>)
# - **SITUER ** (<u>nom 1</u>, <u>nom 2</u>)
